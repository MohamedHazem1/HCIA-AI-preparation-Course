# %%
import pandas as pd
import numpy as np

# %%
dfr=pd.read_csv('/content/train.csv')
dfr
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfs=pd.read_csv('/content/test.csv')
dfs
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
dfr2=dfr.drop(['PassengerId','Parch','Name','Ticket','Cabin','Embarked','SibSp'],axis=True)
dfr2
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
inputs = dfr2.drop(['Survived'],axis=True)
target = dfr2.Survived
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head()
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False
# 3    True  False
# 4   False   True

# %%
inputs2 =pd.concat([inputs,dummies],axis='columns')
inputs2.head()
# Out:
#    Pclass     Sex   Age     Fare  female   male
# 0       3    male  22.0   7.2500   False   True
# 1       1  female  38.0  71.2833    True  False
# 2       3  female  26.0   7.9250    True  False
# 3       1  female  35.0  53.1000    True  False
# 4       3    male  35.0   8.0500   False   True

# %%
inputs3=inputs2.drop(['Sex','female'],axis='columns')
inputs3.head(3)
# Out:
#    Pclass   Age     Fare   male
# 0       3  22.0   7.2500   True
# 1       1  38.0  71.2833  False
# 2       3  26.0   7.9250  False

# %%
inputs3.isnull().sum()
# Out:
# Pclass      0
# Age       177
# Fare        0
# female      0
# male        0
# dtype: int64

# %%
inputs3['Age'].median()
# Out:
# 28.0

# %%
inputs3.Age=inputs3.Age.fillna(inputs.Age.median())
inputs3.head()
# Out:
#    Pclass   Age     Fare   male
# 0       3  22.0   7.2500   True
# 1       1  38.0  71.2833  False
# 2       3  26.0   7.9250  False
# 3       1  35.0  53.1000  False
# 4       3  35.0   8.0500   True

# %% [markdown]
# # Test Data

# %%
dfs2=dfs.drop(['PassengerId','Parch','Name','Ticket','Cabin','Embarked','SibSp'],axis=True)
dfs2.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  34.5   7.8292
# 1       3  female  47.0   7.0000
# 2       2    male  62.0   9.6875
# 3       3    male  27.0   8.6625
# 4       3  female  22.0  12.2875

# %%
test_dum = pd.get_dummies(dfs2.Sex)
test_dum.head()
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2   False   True
# 3   False   True
# 4    True  False

# %%
dfs3 =pd.concat([dfs2,test_dum],axis='columns')
dfs4=dfs3.drop(['Sex','female'],axis='columns')
dfs4.head()
# Out:
#    Pclass   Age     Fare   male
# 0       3  34.5   7.8292   True
# 1       3  47.0   7.0000  False
# 2       2  62.0   9.6875   True
# 3       3  27.0   8.6625   True
# 4       3  22.0  12.2875  False

# %%
inputs3.head()
# Out:
#    Pclass   Age     Fare   male
# 0       3  22.0   7.2500   True
# 1       1  38.0  71.2833  False
# 2       3  26.0   7.9250  False
# 3       1  35.0  53.1000  False
# 4       3  35.0   8.0500   True
