# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from keras.models import Sequential
from keras.layers import Dense
from keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train_resampled.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train_resampled, y_train_resampled, epochs=50, batch_size=32, validation_data=(X_test, y_test))

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8829 - loss: 0.4034 - val_accuracy: 0.9641 - val_loss: 0.1179
# Epoch 2/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - accuracy: 0.9720 - loss: 0.0953 - val_accuracy: 0.9743 - val_loss: 0.0807
# Epoch 3/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9816 - loss: 0.0606 - val_accuracy: 0.9768 - val_loss: 0.0749
# Epoch 4/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9853 - loss: 0.0455 - val_accuracy: 0.9760 - val_loss: 0.0792
# Epoch 5/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9883 - loss: 0.0359 - val_accuracy: 0.9776 - val_loss: 0.0759
# Epoch 6/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9910 - loss: 0.0266 - val_accuracy: 0.9769 - val_loss: 0.0815
# Epoch 7/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9931 - loss: 0.0210 - val_accuracy: 0.9762 - val_loss: 0.0851
# Epoch 8/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9943 - loss: 0.0171 - val_accuracy: 0.9775 - val_loss: 0.0863
# Epoch 9/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9943 - loss: 0.0181 - val_accuracy: 0.9784 - val_loss: 0.0873
# Epoch 10/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9952 - loss: 0.0143 - val_accuracy: 0.9778 - val_loss: 0.0976
# Epoch 11/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9952 - loss: 0.0130 - val_accuracy: 0.9779 - val_loss: 0.0975
# Epoch 12/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9967 - loss: 0.0098 - val_accuracy: 0.9777 - val_loss: 0.1043
# Epoch 13/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9957 - loss: 0.0121 - val_accuracy: 0.9796 - val_loss: 0.0914
# Epoch 14/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9978 - loss: 0.0074 - val_accuracy: 0.9766 - val_loss: 0.1316
# Epoch 15/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.9779 - val_loss: 0.1132
# Epoch 16/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9972 - loss: 0.0084 - val_accuracy: 0.9796 - val_loss: 0.1144
# Epoch 17/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9974 - loss: 0.0077 - val_accuracy: 0.9791 - val_loss: 0.0995
# Epoch 18/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9785 - val_loss: 0.1191
# Epoch 19/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9975 - loss: 0.0073 - val_accuracy: 0.9753 - val_loss: 0.1486
# Epoch 20/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9964 - loss: 0.0107 - val_accuracy: 0.9789 - val_loss: 0.1333
# Epoch 21/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9965 - loss: 0.0098 - val_accuracy: 0.9778 - val_loss: 0.1348
# Epoch 22/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.9767 - val_loss: 0.1440
# Epoch 23/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - accuracy: 0.9973 - loss: 0.0083 - val_accuracy: 0.9761 - val_loss: 0.1604
# Epoch 24/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9972 - loss: 0.0080 - val_accuracy: 0.9774 - val_loss: 0.1488
# Epoch 25/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.9801 - val_loss: 0.1344
# Epoch 26/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9983 - loss: 0.0060 - val_accuracy: 0.9821 - val_loss: 0.1384
# Epoch 27/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9974 - loss: 0.0095 - val_accuracy: 0.9786 - val_loss: 0.1503
# Epoch 28/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.9786 - val_loss: 0.1638
# Epoch 29/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9974 - loss: 0.0078 - val_accuracy: 0.9781 - val_loss: 0.1608
# Epoch 30/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9804 - val_loss: 0.1526
# Epoch 31/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.9783 - val_loss: 0.1576
# Epoch 32/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9978 - loss: 0.0071 - val_accuracy: 0.9780 - val_loss: 0.1643
# Epoch 33/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - accuracy: 0.9981 - loss: 0.0065 - val_accuracy: 0.9773 - val_loss: 0.1761
# Epoch 34/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9980 - loss: 0.0065 - val_accuracy: 0.9796 - val_loss: 0.1629
# Epoch 35/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9979 - loss: 0.0057 - val_accuracy: 0.9800 - val_loss: 0.1720
# Epoch 36/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9983 - loss: 0.0063 - val_accuracy: 0.9801 - val_loss: 0.1592
# Epoch 37/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.9774 - val_loss: 0.1669
# Epoch 38/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9982 - loss: 0.0067 - val_accuracy: 0.9806 - val_loss: 0.1438
# Epoch 39/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9789 - val_loss: 0.1685
# Epoch 40/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9802 - val_loss: 0.1729
# Epoch 41/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9985 - loss: 0.0040 - val_accuracy: 0.9800 - val_loss: 0.1879
# Epoch 42/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9980 - loss: 0.0085 - val_accuracy: 0.9807 - val_loss: 0.1679
# Epoch 43/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9789 - val_loss: 0.1629
# Epoch 44/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.9785 - val_loss: 0.2055
# Epoch 45/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9979 - loss: 0.0090 - val_accuracy: 0.9792 - val_loss: 0.1830
# Epoch 46/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9991 - loss: 0.0035 - val_accuracy: 0.9771 - val_loss: 0.2022
# Epoch 47/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9779 - val_loss: 0.2093
# Epoch 48/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9985 - loss: 0.0058 - val_accuracy: 0.9813 - val_loss: 0.1813
# Epoch 49/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.9793 - val_loss: 0.1966
# Epoch 50/50
# 2107/2107 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9786 - val_loss: 0.2049
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
accuracy = accuracy_score(y_test, y_pred_classes)
print("Accuracy:", accuracy)

print(classification_report(y_test, y_pred_classes))
print(confusion_matrix(y_test, y_pred_classes))
# Out:
# Accuracy: 0.9786
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.97      1032
#            3       0.99      0.98      0.98      1010
#            4       0.98      0.97      0.97       982
#            5       0.97      0.98      0.98       892
#            6       0.98      0.98      0.98       958
#            7       0.99      0.97      0.98      1028
#            8       0.96      0.98      0.97       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
#
# [[ 970    1    0    0    0    1    3    2    2    1]
#  [   0 1123    3    0    0    0    1    2    6    0]
#  [   6    0 1002    3    4    0    4    3   10    0]
#  [   2    0    6  990    0    5    0    0    4    3]
#  [   0    0    4    0  951    1    7    2    2   15]
#  [   3    0    0    7    1  872    3    1    1    4]
#  [   3    2    0    0    1    6  943    0    3    0]
#  [   3    3    9    2    2    0    0  995   10    4]
#  [   4    1    1    0    3    4    0    3  958    0]
#  [   1    2    2    0   10    6    0    0    6  982]]

# %%
# Out:
# 0.9786
