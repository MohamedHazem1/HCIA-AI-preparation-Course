# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from keras.models import *
from keras.layers import *
from keras.datasets import cifar10
from keras.datasets import mnist
from keras.layers import MaxPooling2D

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
model = Sequential()
model.add(Conv2D(32,kernel_size= (3, 3), activation='relu', padding='same', input_shape=(32, 32,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64,kernel_size= (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 391/391 [==============================] - 11s 26ms/step - loss: 1.5587 - accuracy: 0.4356 - val_loss: 1.2880 - val_accuracy: 0.5353
# Epoch 2/50
# 391/391 [==============================] - 10s 25ms/step - loss: 1.1215 - accuracy: 0.6050 - val_loss: 1.0416 - val_accuracy: 0.6322
# Epoch 3/50
# 391/391 [==============================] - 10s 25ms/step - loss: 0.9458 - accuracy: 0.6700 - val_loss: 0.9647 - val_accuracy: 0.6618
# Epoch 4/50
# 391/391 [==============================] - 10s 25ms/step - loss: 0.8381 - accuracy: 0.7073 - val_loss: 0.8983 - val_accuracy: 0.6878
# Epoch 5/50
# 391/391 [==============================] - 10s 25ms/step - loss: 0.7500 - accuracy: 0.7372 - val_loss: 0.8879 - val_accuracy: 0.6936
# Epoch 6/50
# 391/391 [==============================] - 10s 25ms/step - loss: 0.6648 - accuracy: 0.7677 - val_loss: 0.8233 - val_accuracy: 0.7208
# Epoch 7/50
# ...

# %% [markdown]
# # **Basic LENET-5**

# %%
model2 = Sequential()

model2.add(Conv2D(6, kernel_size=(5, 5), activation='tanh', input_shape=(32, 32, 3)))
model2.add(AveragePooling2D(pool_size=(2, 2)))
model2.add(Conv2D(16, kernel_size=(5, 5), activation='tanh'))
model2.add(AveragePooling2D(pool_size=(2, 2)))
model2.add(Flatten())
model2.add(Dense(120, activation='tanh'))
model2.add(Dense(84, activation='tanh'))
model2.add(Dense(10, activation='softmax'))

model2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model2.fit(x_train, y_train, batch_size=128, epochs=10, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.8278 - accuracy: 0.3549 - val_loss: 1.7127 - val_accuracy: 0.3986
# Epoch 2/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.6456 - accuracy: 0.4192 - val_loss: 1.5673 - val_accuracy: 0.4479
# Epoch 3/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.5097 - accuracy: 0.4641 - val_loss: 1.4593 - val_accuracy: 0.4773
# Epoch 4/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.4157 - accuracy: 0.4964 - val_loss: 1.4423 - val_accuracy: 0.4883
# Epoch 5/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.3544 - accuracy: 0.5167 - val_loss: 1.3567 - val_accuracy: 0.5156
# Epoch 6/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.2990 - accuracy: 0.5381 - val_loss: 1.3439 - val_accuracy: 0.5169
# Epoch 7/10
# ...

# %% [markdown]
# # **LENET on MINSET**

# %%
(x_train1, y_train1), (x_test1, y_test1) = mnist .load_data()
x_train1 = x_train1.astype('float32')
x_test1 = x_test1.astype('float32')
x_train1 /= 255
x_test1 /= 255

# %%
model3 = Sequential()

model3.add(Conv2D(6, kernel_size=(5, 5), activation='tanh', input_shape=(32, 32, 3)))
model3.add(AveragePooling2D(pool_size=(2, 2)))
model3.add(Conv2D(16, kernel_size=(5, 5), activation='tanh'))
model3.add(AveragePooling2D(pool_size=(2, 2)))
model3.add(Conv2D(120, kernel_size=(5, 5), activation='tanh'))

model3.add(Flatten())
model3.add(Dense(120, activation='tanh'))
model3.add(Dense(84, activation='tanh'))
model3.add(Dense(10, activation='softmax'))

model3.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model3.fit(x_train1, y_train1, batch_size=128, epochs=10, verbose=1, validation_data=(x_test1, y_test1))
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-af32fb3085ef> in <cell line: 1>()
# ----> 1 model3.fit(x_train1, y_train1, batch_size=128, epochs=10, verbose=1, validation_data=(x_test1, y_test1))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
# Import necessary modules
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
import numpy as np

# Load MNIST dataset
(x_train1, y_train1), (x_test1, y_test1) = mnist.load_data()


# Normalize pixel values
x_train1 = x_train1.astype('float32') / 255.0
x_test1 = x_test1.astype('float32') / 255.0

# %%
x_train1.shape
# Out:
# (60000, 28, 28)

# %%
# Define model with correct input shape and padding
model3 = Sequential()
model3.add(Conv2D(6, kernel_size=(5, 5), activation='tanh', input_shape=(28, 28, 1), padding='same'))  # Added padding
model3.add(MaxPooling2D(pool_size=(2, 2),strides=(2,2)))
model3.add(Conv2D(16, kernel_size=(5, 5), activation='tanh', padding='same'))  # Added padding
model3.add(MaxPooling2D(pool_size=(2, 2),strides=(2,2)))
model3.add(Conv2D(120, kernel_size=(5, 5), activation='tanh', padding='valid'))  # You can keep this as 'valid' or change to 'same'
model3.add(Flatten())
model3.add(Dense(120, activation='tanh'))
model3.add(Dense(64, activation='tanh'))
model3.add(Dense(10, activation='softmax'))

model3.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# prompt: max pooling with its import

from keras.layers import MaxPooling2D

model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
# Train the model
model3.fit(x_train1, y_train1, batch_size=128, epochs=10, verbose=1, validation_data=(x_test1, y_test1))
# Out:
# Epoch 1/10
#  30/469 ━━━━━━━━━━━━━━━━━━━━ 50s 116ms/step - accuracy: 0.5335 - loss: 1.5998
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ccaff2a76358> in <cell line: 2>()
#       1 # Train the model
# ----> 2 model3.fit(x_train1, y_train1, batch_size=128, epochs=10, verbose=1, validation_data=(x_test1, y_test1))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
